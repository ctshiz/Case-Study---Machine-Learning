# %%
import pandas as pd
from matplotlib import pyplot as plt

healthcare = pd.read_csv("healthcarecostUS.csv")

#Inspect the first 5 rows of healthcare
print(healthcare.head())
# Out:
#                              DRG Definition  Provider Id  \
# 0  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10001
# 1  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10005
# 2  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10006
# 3  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10011
# 4  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10016
#
#                       Provider Name     Provider Street Address Provider City  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE        DOTHAN
# 1     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH          BOAZ
# 2    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET      FLORENCE
# 3                 ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE    BIRMINGHAM
# 4     SHELBY BAPTIST MEDICAL CENTER     1000 FIRST STREET NORTH     ALABASTER
#
#   Provider State  Provider Zip Code Hospital Referral Region Description  \
# 0             AL              36301                          AL - Dothan
# ...

# %%
#Inspect all the columns keys of the dataframe
health_column = healthcare.columns
print(health_column)
# Out:
# Index(['DRG Definition', 'Provider Id', 'Provider Name',
#        'Provider Street Address', 'Provider City', 'Provider State',
#        'Provider Zip Code', 'Hospital Referral Region Description',
#        ' Total Discharges ', ' Average Covered Charges ',
#        ' Average Total Payments ', 'Average Medicare Payments'],
#       dtype='object')

# %%
#Inspect the DRG Definition column.
print(healthcare["DRG Definition"].unique())
# Out:
# ['039 - EXTRACRANIAL PROCEDURES W/O CC/MCC' '101 - SEIZURES W/O MCC'
#  '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC'
#  '149 - DYSEQUILIBRIUM' '069 - TRANSIENT ISCHEMIA' '313 - CHEST PAIN'
#  '064 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W MCC'
#  '065 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W CC'
#  '603 - CELLULITIS W/O MCC' '638 - DIABETES W CC'
#  '066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W/O CC/MCC'
#  '074 - CRANIAL & PERIPHERAL NERVE DISORDERS W/O MCC'
#  '176 - PULMONARY EMBOLISM W/O MCC'
#  '177 - RESPIRATORY INFECTIONS & INFLAMMATIONS W MCC'
#  '189 - PULMONARY EDEMA & RESPIRATORY FAILURE'
#  '178 - RESPIRATORY INFECTIONS & INFLAMMATIONS W CC'
#  '190 - CHRONIC OBSTRUCTIVE PULMONARY DISEASE W MCC'
#  '191 - CHRONIC OBSTRUCTIVE PULMONARY DISEASE W CC'
#  '193 - SIMPLE PNEUMONIA & PLEURISY W MCC'
#  '194 - SIMPLE PNEUMONIA & PLEURISY W CC'
#  '192 - CHRONIC OBSTRUCTIVE PULMONARY DISEASE W/O CC/MCC'
# ...

# %%
#Let's focus primarly on procedures related to respiratory diseases
prodecure_176 = healthcare[healthcare['DRG Definition'] == '176 - PULMONARY EMBOLISM W/O MCC']
#print(prodecure_176)
prodecure_177 = healthcare[healthcare['DRG Definition'] == '177 - RESPIRATORY INFECTIONS & INFLAMMATIONS W MCC']
#print(prodecure_177)
prodecure_178 = healthcare[healthcare['DRG Definition'] == '178 - RESPIRATORY INFECTIONS & INFLAMMATIONS W CC']
#print(prodecure_178)
prodecure_189 = healthcare[healthcare['DRG Definition'] == '189 - PULMONARY EDEMA & RESPIRATORY FAILURE']
#print(prodecure_189)
prodecure_190 = healthcare[healthcare['DRG Definition'] == '190 - CHRONIC OBSTRUCTIVE PULMONARY DISEASE W MCC']
#print(prodecure_190)
prodecure_191 = healthcare[healthcare['DRG Definition'] == '191 - CHRONIC OBSTRUCTIVE PULMONARY DISEASE W CC']
#print(prodecure_191)
prodecure_192 = healthcare[healthcare['DRG Definition'] == '192 - CHRONIC OBSTRUCTIVE PULMONARY DISEASE W/O CC/MCC']
#print(prodecure_192)
prodecure_193 = healthcare[healthcare['DRG Definition'] == '193 - SIMPLE PNEUMONIA & PLEURISY W MCC']
#print(prodecure_193)
prodecure_194 = healthcare[healthcare['DRG Definition'] == '194 - SIMPLE PNEUMONIA & PLEURISY W CC']
#print(prodecure_194)
prodecure_195 = healthcare[healthcare['DRG Definition'] == '195 - SIMPLE PNEUMONIA & PLEURISY W/O CC/MCC']
#print(prodecure_195)
prodecure_202 = healthcare[healthcare['DRG Definition'] == '202 - BRONCHITIS & ASTHMA W CC/MCC']
#print(prodecure_202)
prodecure_203 = healthcare[healthcare['DRG Definition'] == '203 - BRONCHITIS & ASTHMA W/O CC/MCC']
#print(prodecure_203)
prodecure_207 = healthcare[healthcare['DRG Definition'] == '207 - RESPIRATORY SYSTEM DIAGNOSIS W VENTILATOR SUPPORT 96+ HOURS']
#print(prodecure_207)

# %%
#Create a list with all the US states and create a dataset 
states = prodecure_176['Provider State'].unique()
print(states)


datasets_176 = []
datasets_177 = []
datasets_178 = []
datasets_189 = []
datasets_190 = []
datasets_191 = []
datasets_192 = []
datasets_193 = []
datasets_194 = []
datasets_195 = []
datasets_202 = []
datasets_203 = []
datasets_207 = []
for state in states:
    datasets_176.append(prodecure_176[prodecure_176['Provider State'] == state][' Average Covered Charges '].values)
    datasets_177.append(prodecure_177[prodecure_177['Provider State'] == state][' Average Covered Charges '].values)
    datasets_178.append(prodecure_178[prodecure_178['Provider State'] == state][' Average Covered Charges '].values)
    datasets_189.append(prodecure_189[prodecure_189['Provider State'] == state][' Average Covered Charges '].values)
    datasets_190.append(prodecure_190[prodecure_190['Provider State'] == state][' Average Covered Charges '].values)
    datasets_191.append(prodecure_191[prodecure_191['Provider State'] == state][' Average Covered Charges '].values)
    datasets_192.append(prodecure_192[prodecure_192['Provider State'] == state][' Average Covered Charges '].values)
    datasets_193.append(prodecure_193[prodecure_193['Provider State'] == state][' Average Covered Charges '].values)
    datasets_194.append(prodecure_194[prodecure_194['Provider State'] == state][' Average Covered Charges '].values)
    datasets_195.append(prodecure_195[prodecure_195['Provider State'] == state][' Average Covered Charges '].values)
    datasets_202.append(prodecure_202[prodecure_202['Provider State'] == state][' Average Covered Charges '].values)
    datasets_203.append(prodecure_203[prodecure_203['Provider State'] == state][' Average Covered Charges '].values)
    datasets_207.append(prodecure_207[prodecure_207['Provider State'] == state][' Average Covered Charges '].values)
# Out:
# ['AL' 'AK' 'AZ' 'AR' 'CA' 'CO' 'CT' 'DE' 'DC' 'FL' 'GA' 'HI' 'ID' 'IL'
#  'IN' 'IA' 'KS' 'KY' 'LA' 'ME' 'MD' 'MA' 'MI' 'MN' 'MS' 'MO' 'MT' 'NE'
#  'NV' 'NH' 'NJ' 'NM' 'NY' 'NC' 'ND' 'OH' 'OK' 'OR' 'PA' 'RI' 'SC' 'SD'
#  'TN' 'TX' 'UT' 'VT' 'VA' 'WA' 'WV' 'WI' 'WY']

# %%
plt.figure(figsize=(20,6))
plt.title("Healthcare charged per State - 176 - PULMONARY EMBOLISM W/O MCC")
plt.xlabel("States")
plt.ylabel("Average Covered Charges")
plt.boxplot(datasets_176, labels = states)
plt.show()
# Out:
# c:\python38\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
plt.figure(figsize=(20,6))
plt.title("Healthcare charged per State - 177 - RESPIRATORY INFECTIONS & INFLAMMATIONS W MCC")
plt.xlabel("States")
plt.ylabel("Average Covered Charges")
plt.boxplot(datasets_177, labels = states)
plt.show()
# Out:
# c:\python38\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
plt.figure(figsize=(20,6))
plt.title("Healthcare charged per State - 178 - RESPIRATORY INFECTIONS & INFLAMMATIONS W CC")
plt.xlabel("States")
plt.ylabel("Average Covered Charges")
plt.boxplot(datasets_178, labels = states)
plt.show()
# Out:
# c:\python38\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
plt.figure(figsize=(20,6))
plt.title("Healthcare charged per State - '189 - PULMONARY EDEMA & RESPIRATORY FAILURE'")
plt.xlabel("States")
plt.ylabel("Average Covered Charges")
plt.boxplot(datasets_189, labels = states)
plt.show()
# Out:
# c:\python38\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
plt.figure(figsize=(20,6))
plt.title("Healthcare charged per State - '190 - CHRONIC OBSTRUCTIVE PULMONARY DISEASE W MCC'")
plt.xlabel("States")
plt.ylabel("Average Covered Charges")
plt.boxplot(datasets_190, labels = states)
plt.show()
# Out:
# c:\python38\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
plt.figure(figsize=(20,6))
plt.title("Healthcare charged per State - '191 - CHRONIC OBSTRUCTIVE PULMONARY DISEASE W CC'")
plt.xlabel("States")
plt.ylabel("Average Covered Charges")
plt.boxplot(datasets_191, labels = states)
plt.show()
# Out:
# c:\python38\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
plt.figure(figsize=(20,6))
plt.title("Healthcare charged per State - '192 - CHRONIC OBSTRUCTIVE PULMONARY DISEASE W/O CC/MCC'")
plt.xlabel("States")
plt.ylabel("Average Covered Charges")
plt.boxplot(datasets_192, labels = states)
plt.show()
# Out:
# c:\python38\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
plt.figure(figsize=(20,6))
plt.title("Healthcare charged per State - '193 - SIMPLE PNEUMONIA & PLEURISY W MCC'")
plt.xlabel("States")
plt.ylabel("Average Covered Charges")
plt.boxplot(datasets_193, labels = states)
plt.show()
# Out:
# c:\python38\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
plt.figure(figsize=(20,6))
plt.title("Healthcare charged per State - '194 - SIMPLE PNEUMONIA & PLEURISY W CC'")
plt.xlabel("States")
plt.ylabel("Average Covered Charges")
plt.boxplot(datasets_194, labels = states)
plt.show()
# Out:
# c:\python38\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
plt.figure(figsize=(20,6))
plt.title("Healthcare charged per State - '195 - SIMPLE PNEUMONIA & PLEURISY W/O CC/MCC'")
plt.xlabel("States")
plt.ylabel("Average Covered Charges")
plt.boxplot(datasets_195, labels = states)
plt.show()
# Out:
# c:\python38\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
plt.figure(figsize=(20,6))
plt.title("Healthcare charged per State - '202 - BRONCHITIS & ASTHMA W CC/MCC'")
plt.xlabel("States")
plt.ylabel("Average Covered Charges")
plt.boxplot(datasets_202, labels = states)
plt.show()
# Out:
# c:\python38\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
plt.figure(figsize=(20,6))
plt.title("Healthcare charged per State - '203 - BRONCHITIS & ASTHMA W/O CC/MCC'")
plt.xlabel("States")
plt.ylabel("Average Covered Charges")
plt.boxplot(datasets_203, labels = states)
plt.show()
# Out:
# c:\python38\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
plt.figure(figsize=(20,6))
plt.title("Healthcare charged per State - '207 - RESPIRATORY SYSTEM DIAGNOSIS W VENTILATOR SUPPORT 96+ HOURS'")
plt.xlabel("States")
plt.ylabel("Average Covered Charges")
plt.boxplot(datasets_207, labels = states)
plt.show()
# Out:
# c:\python38\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
